# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("Yields_NaN.xlsx")

# %%
df.head()
index_float = pd.date_range("1970-01-01", freq="M", periods=574)
df.set_index(index_float, inplace=True)
df.head()
# Out:
#             3-Month DEU  3-Month ESP  3-Month FRA  3-Month GBR  3-Month IRL  \
# 1970-01-31         9.29        5.305        10.35         6.06        4.475
# 1970-02-28         9.51          NaN         9.86          NaN          NaN
# 1970-03-31         9.81          NaN         9.55          NaN          NaN
# 1970-04-30         9.86          NaN         8.95          NaN          NaN
# 1970-05-31         9.93          NaN         9.02          NaN          NaN
#
#             3-Month ITA  3-Month NLD  10-Year DEU  10-Year ESP  10-Year FRA  \
# 1970-01-31         5.23          3.6          7.6        5.645         8.74
# 1970-02-28          NaN          NaN          7.8          NaN         8.84
# 1970-03-31          NaN          NaN          8.1          NaN         8.76
# 1970-04-30          NaN          NaN          8.1          NaN         8.63
# 1970-05-31          NaN          NaN          8.4          NaN         8.62
#
# ...

# %%
df_interp = df.interpolate(method="linear")

# %%
df_interp.plot()
df_interp.to_excel("Yields_Interpolated.xlsx")
