# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("GDP_Growth.csv.xlsx", index_col=0)

# %%
Country = ("DEU", "ESP", "EU", "FRA", "GBR", "IRL", "ITA", "NLD")

# %%
df.head()
# Out:
#              DEU       ESP   FRA   GBR       IRL       ITA       NLD        EU
# DATE
# 1970-01-01 -1.59  1.869665  1.91 -0.62  1.700898  5.990000 -1.492127  0.819700
# 1970-04-01  3.98  0.158864  1.26  2.34 -0.590195  0.729987  2.729327  2.227681
# 1970-07-01  1.87  0.511083  1.38  1.00  0.019110  2.006338  1.530089  1.511179
# 1970-10-01  0.85  0.789028  1.57  0.86  0.552682  0.111821  2.075318  0.947731
# 1971-01-01 -1.92  0.780918  0.13 -0.57  0.989664 -0.523041  0.488356 -0.692962

# %%
df.plot()

# %%
df.describe()
# Out:
#               DEU         ESP         FRA         GBR         IRL         ITA  \
# count  191.000000  191.000000  191.000000  191.000000  191.000000  191.000000
# mean     0.502147    0.640166    0.536126    0.555445    1.138628    0.453392
# std      0.973626    0.793281    0.558832    0.923513    1.520165    0.946500
# min     -4.490000   -1.921754   -1.640000   -2.730000   -3.843707   -2.750000
# 25%     -0.020000    0.210927    0.190000    0.175000    0.416255   -0.042654
# 50%      0.470000    0.710000    0.530000    0.600000    1.014409    0.390000
# 75%      1.005000    1.025000    0.850000    0.935000    1.817750    0.841152
# max      3.980000    3.781683    1.990000    4.950000    7.044086    5.990000
#
#               NLD          EU
# count  191.000000  191.000000
# mean     0.573376    0.534248
# std      1.139630    0.609000
# min     -4.905977   -2.620732
# 25%      0.135651    0.270608
# 50%      0.630000    0.533407
# 75%      1.109440    0.841500
# ...

# %%
df.idxmax()
# Out:
# DEU   1970-04-01
# ESP   1990-10-01
# FRA   1973-01-01
# GBR   1973-01-01
# IRL   1999-01-01
# ITA   1970-01-01
# NLD   1979-04-01
# EU    1979-04-01
# dtype: datetime64[ns]

# %%
df_upsmpl = df.resample("M").mean()

# %%
df_upsmpl.head()
# Out:
#              DEU       ESP   FRA   GBR       IRL       ITA       NLD        EU
# DATE
# 1970-01-31 -1.59  1.869665  1.91 -0.62  1.700898  5.990000 -1.492127  0.819700
# 1970-02-28   NaN       NaN   NaN   NaN       NaN       NaN       NaN       NaN
# 1970-03-31   NaN       NaN   NaN   NaN       NaN       NaN       NaN       NaN
# 1970-04-30  3.98  0.158864  1.26  2.34 -0.590195  0.729987  2.729327  2.227681
# 1970-05-31   NaN       NaN   NaN   NaN       NaN       NaN       NaN       NaN

# %%
df_upsmpl.interpolate(inplace=True)

# %%
df.head()
# Out:
#              DEU       ESP   FRA   GBR       IRL       ITA       NLD        EU
# DATE
# 1970-01-01 -1.59  1.869665  1.91 -0.62  1.700898  5.990000 -1.492127  0.819700
# 1970-04-01  3.98  0.158864  1.26  2.34 -0.590195  0.729987  2.729327  2.227681
# 1970-07-01  1.87  0.511083  1.38  1.00  0.019110  2.006338  1.530089  1.511179
# 1970-10-01  0.85  0.789028  1.57  0.86  0.552682  0.111821  2.075318  0.947731
# 1971-01-01 -1.92  0.780918  0.13 -0.57  0.989664 -0.523041  0.488356 -0.692962

# %%
df_upsmpl.to_excel("GDP_Growth_Monthly.xlsx")
