# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
#plt.style.use('fivethirtyeight')
plt.style.use('bmh')

# %%
df = pd.read_excel("Graphs.xlsx", index_col=0, sheetname="SVM_DEU_GBR")

# %%
df.head()
# Out:
#             PRED  ACTUAL  S_DEU  S_GBR
# DATE
# 2006-01-31     0       0   0.81  -0.46
# 2006-02-28     0       0   0.87  -0.37
# 2006-03-31     0       0   0.92  -0.21
# 2006-04-30     0       0   1.10  -0.05
# 2006-05-31     0       0   1.07   0.00

# %%
df[["PRED", "ACTUAL"]].plot()
df["S_DEU"].plot()
df["S_GBR"].plot(marker = "+")
plt.legend(df)
plt.title("DEU, GBR")
plt.savefig("../Graphs/DEU, GBR.png", dpi=100)

# %%
df1 = pd.read_excel("Graphs.xlsx", index_col=0, sheetname="SVM_DEU_FRA_ITA")
df1.head()
# Out:
#             PRED  ACTUAL  S_DEU  S_FRA  S_ITA
# DATE
# 2006-01-31     0       0   0.81   0.83   1.03
# 2006-02-28     0       0   0.87   0.91   1.10
# 2006-03-31     0       0   0.92   0.97   1.20
# 2006-04-30     0       0   1.10   1.16   1.43
# 2006-05-31     0       0   1.07   1.11   1.39

# %%
df1[["PRED", "ACTUAL"]].plot()
df1["S_DEU"].plot()
df1["S_FRA"].plot(marker = "+")
df1["S_ITA"].plot(marker = "v")
plt.legend(df1)
plt.title("DEU, FRA, ITA")
plt.savefig("../Graphs/DEU, FRA, ITA.png", dpi=100)

# %%
df2 = pd.read_excel("Graphs.xlsx", index_col=0, sheetname="SVM_DEU_FRA")
df2.head()
# Out:
#             PRED  ACTUAL  S_DEU  S_FRA
# DATE
# 2006-01-31     0       0   0.81   0.83
# 2006-02-28     0       0   0.87   0.91
# 2006-03-31     0       0   0.92   0.97
# 2006-04-30     0       0   1.10   1.16
# 2006-05-31     0       0   1.07   1.11

# %%
df2[["PRED", "ACTUAL"]].plot()
df2["S_DEU"].plot()
df2["S_FRA"].plot(marker = "+")
#df2["S_ITA"].plot(marker = "v")
plt.legend(df2)
plt.title("DEU, FRA")
plt.savefig("../Graphs/'DEU, FRA.png", dpi=100)

# %%
df3 = pd.read_excel("Graphs.xlsx", index_col=0, sheetname="SVM_DEU_GRID")

# %%
df3[["PRED", "ACTUAL"]].plot()
#df3["S_FRA"].plot(marker = "+")
#df2["S_ITA"].plot(marker = "v")
df3["S_DEU"].plot()
plt.legend(df3)
plt.title("DEU Adjusted")
plt.savefig("../Deliver/Graphs/DEU Adjusted.png", dpi=100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-62-4ae0ab8c495c> in <module>()
#       5 plt.legend(df3)
#       6 plt.title("DEU Adjusted")
# ----> 7 plt.savefig("../Deliver/Graphs/DEU Adjusted.png", dpi=100)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    1812             self.set_frameon(frameon)
#    1813
# -> 1814         self.canvas.print_figure(fname, **kwargs)
#    1815
#    1816         if frameon:
#
# ...

# %%
df4 = pd.read_excel("Graphs.xlsx", index_col=0, sheetname="SVM_DEU_NO_GRID")

# %%
df4[["PRED", "ACTUAL"]].plot()
#df3["S_FRA"].plot(marker = "+")
#df2["S_ITA"].plot(marker = "v")
df4["S_DEU"].plot()
plt.legend(df4)
plt.title("DEU")
plt.savefig("../Graphs/DEU.png", dpi=100)

# %%
df5 = pd.read_excel("Graphs.xlsx", index_col=0, sheetname="SVM_WAV")

# %%
df5[["PRED", "ACTUAL"]].plot()
#df3["S_FRA"].plot(marker = "+")
#df2["S_ITA"].plot(marker = "v")
df5["S_WAV"].plot(color="g")
plt.legend(df5)
plt.title("WAV")
plt.savefig("../Graphs/WAV.png", dpi=100)

# %%
df6 = pd.read_excel("Graphs.xlsx", index_col=0, sheetname="Spread")
df6.head()
# Out:
#                S_WAV     G_WAV  Recession
# 1970-01-01 -0.135695  0.819700          0
# 1970-02-01 -0.058400  1.286738          0
# 1970-03-01 -0.042632  1.758106          0
# 1970-04-01  0.037857  2.233664          0
# 1970-05-01  0.136605  1.994116          0

# %%
df6["Recession"].plot()
#df3["S_FRA"].plot(marker = "+")
#df2["S_ITA"].plot(marker = "v")
df6["S_WAV"].plot(color="g")
df6["G_WAV"].plot(marker ="+")
plt.legend()
plt.title("Recessions")
plt.savefig("../Graphs/Recessions.png", dpi=100)
